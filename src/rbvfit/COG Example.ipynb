# %% [markdown]
# # Example Notebook Showing how to create and plot the curve of growth

# %%
from rbvfit import compute_cog as c
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Traceback (most recent call last):
#
#   File "/Users/bordoloi/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-10-4087c0535629>", line 1, in <module>
#     from rbvfit import compute_cog as c
#
#   File "/Users/bordoloi/WORK/python/rbvfit/src/rbvfit/compute_cog.py", line 57
#     self.st=rt.rb_setline(lam_guess,'closest')
#                                               ^
# IndentationError: unindent does not match any outer indentation level

# %%
#create a series of column densities for which COG is computed
Nlist=np.arange(11.5,20.,.1)

#create b value lists for which COG is computed
blist=np.array([15.,20.,30.,50.])

#Wavelength of transition in angstrom
lam_guess= 2796.3

#create the COG object
s=c.compute_cog(lam_guess,Nlist,blist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c64a00f7eb0b> in <module>
#       1 #create a series of column densities for which COG is computed
# ----> 2 Nlist=np.arange(11.5,20.,.1)
#       3
#       4 #create b value lists for which COG is computed
#       5 blist=np.array([15.,20.,30.,50.])
#
# NameError: name 'np' is not defined

# %%
#plot the computed COG

s.plot_cog()

# %%
# Extract values from object

# Matrix of EWs 
Wlist=s.Wlist


#recreate the plot above

#Convert Angstrom to cm
plt.title(s.st['name'])
for i in range (0,len(blist)):
    plt.plot(np.log10((10**Nlist)*s.st['fval']*s.st['wave']*1e-8),np.log10(Wlist[:,i]/s.st['wave']),label='b = '+ np.str(blist[i]))
plt.xlabel(r'$log_{10} [N f \lambda]$')
plt.ylabel(r'$log_{10} [W/ \lambda]$')

plt.legend()
