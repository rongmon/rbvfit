# %% [markdown]
# # This is an examples of how to use the rb_vfit program
#
#
# ## Written By: Rongmon Bordoloi
# Dec 14, 2020
# Tested on Python 3.7

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np
from importlib import reload

from linetools.spectra.xspectrum1d import XSpectrum1D  

import rb_interactive_vpfit as m
reload(m)
# Out:
# <module 'rb_interactive_vpfit' from '/Users/bordoloi/WORK/python/rbvfit/src/rbvfit/rb_interactive_vpfit.py'>

# %%
filename='/Users/bordoloi/Dropbox/COS-Pairs/Targets/J2228-0950/Data/J2228-0950_nbin3_coadd_wc.fits'
sp=XSpectrum1D.from_file(filename)

# %%
wave=sp.wavelength.value
flux=sp.flux.value/sp.co.value
error=sp.sig.value/sp.co.value

q=np.isnan(flux)
flux[q]
# Out:
# array([], dtype=float32)

# %%
q=np.where((wave >1775) & (wave < 1785))
wave=wave[q]
flux=flux[q]
error=error[q]

# %%
wrest=[1215.06]
ntransition=1
zabs=[0.46494]
guess=[17.0,30.,0.]
xrange=[-600.,600.]


m.rb_interactive_vpfit(wave,flux,error,wrest,zabs,ntransition=ntransition,custom_guess=guess,FWHM=6.5,xrange=xrange)
# Out:
# [array([ 15.,  10., -50.]), array([19., 50., 50.])]
# [ 18.70748297  10.         -39.42427449]
# 18.557881518806806 18.857084431024806
# -139.5198553443731 159.5198553443731
# -52.93157809136473 -25.916970884911834
# <img src="data:image/png;base64,..." width="640">

# %%
def test(guess=False):
    if guess==False:
        print(huzzah)
    else:
        guess=guess
        print(guess)

# %%
test(guess=[12,12])
# Out:
# [12, 12]

# %%
sp.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
